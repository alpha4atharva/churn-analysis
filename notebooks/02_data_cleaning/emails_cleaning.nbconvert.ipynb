# %%
import pandas as pd
import numpy as np

# %%
emails = pd.read_csv('../../data/raw/emails.csv', low_memory=False)
emails.shape
# Out:
# (123389, 27)

# %% [markdown]
# Standardizing Column Names

# %%
emails.columns = (emails.columns.str.lower())
emails.columns
# Out:
# Index(['co_ref', 'time_to_renewal', 'crm_accreditation_completed',
#        'crm_timely_completion', 'crm_progress_towards_accreditation',
#        'crm_delays_in_accreditation', 'crm_contractor_suggested_leave',
#        'crm_contractor_engagement', 'crm_contractor_sentiment',
#        'crm_contractor_sentiment_score', 'crm_dts_or_ssip_mentioned',
#        'crm_customer_payment_intention', 'crm_competitors_mentioned',
#        'crm_membership_level', 'crm_platform_issues_raised',
#        'crm_agent_chased_contractor', 'crm_agent_chase_count',
#        'crm_accreditation_issues', 'crm_membership_overdue',
#        'crm_auto_renewal_status', 'crm_dissatisified_with_renewal_price',
#        'crm_customer_complained', 'crm_refund_mentioned',
#        'crm_negative_customer_experience', 'crm_dissatisfaction_with_support',
#        'crm_financial_hardship_mentioned', 'year'],
#       dtype='str')

# %%
emails['time_to_renewal'].value_counts()
# Out:
# time_to_renewal
# prior_year     40022
# 14_out         32493
# 45_out         28008
# pre_renewal    22866
# Name: count, dtype: int64

# %% [markdown]
# Checking duplicates

# %%
emails.duplicated().sum()
# Out:
# np.int64(0)

# %%
emails['co_ref'].isnull().sum()
# Out:
# np.int64(0)

# %%
emails['time_to_renewal'].value_counts()
# Out:
# time_to_renewal
# prior_year     40022
# 14_out         32493
# 45_out         28008
# pre_renewal    22866
# Name: count, dtype: int64

# %% [markdown]
# Dropping irrelevant columns<br>
# year -> can be derived

# %%
emails['year'].unique()
# Out:
# array([2025, 2026, 2024])

# %%
emails = emails.drop('year', axis=1)
emails= emails.drop('time_to_renewal', axis=1)
emails.shape
# Out:
# (123389, 25)

# %% [markdown]
# Handling missing values

# %%
emails= emails.apply(lambda col: col.fillna("Unknown"))

# %% [markdown]
# Standardized Categorical values

# %%
emails['crm_delays_in_accreditation'].unique()
# Out:
# <StringArray>
# [                                                                                                                                                                                                              'Yes',
#                                                                                                                                                                                                                 'No',
#                                                                                                                                                                                                      'Not Discussed',
#                                                                                                       'Not Discussed (However, I must answer Yes or No, so I'll choose No as there's no clear indication of delays)',
#                                      'Not Discussed is not applicable here as there is no mention of accreditation delays, however, the answer to whether there are any delays based on the content provided is: No',
#                                                                                                                                                                                                            'Unknown',
#                                                                                                                                                     'Not Discussed is not applicable here, so I will default to: No',
#                                                                                         'Not Discussed but potentially yes as the customer is trying to contact Ian and was told he may be in later or the next day',
#  'Not Discussed (However, considering the context is about a policy and a phone number with no answer, it might imply a delay or issue, but strictly speaking, delays in accreditation are not directly mentioned.)',
#                                                                                       'Not Discussed, however, I can infer that there might be a delay since it's been 27+ days with no call, so I will answer: Yes',
#                                                                                                                                                        'Not Discussed is not an option here so I will default to No',
#                                                                   '"Not Discussed (However, since there is no information about accreditation delays, the most fitting answer from the options provided is ""No"")"',
#                                                                                                          'Not Discussed is not applicable here as there is no information about delays, so the answer should be: No',
#                                                                                        '"Not Discussed (However, since the question requires a Yes/No answer, I'll provide ""No"" as there's no mention of delays)"',
#                                                                                                                  'Not Discussed is not an option for this prompt, I will choose No as there is no mention of delays',
#                                                                                                                                                      'Not Discussed but potentially yes as a reason for the AR call',
#                                                                                           'Not Discussed is not applicable here as there is no information about accreditation delays, so the correct answer is: No',
#                                                                                                                                              'Not Discussed is not an option here so the most suitable answer is No',
#                                                                                                                                                          'Not Discussed but potentially yes due to lack of progress']
# Length: 19, dtype: str

# %%
mapping = {
    "Yes": "Yes",
    "No": "No",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown",

    "Not Discussed (However, I must answer Yes or No, so I'll choose No as there's no clear indication of delays)": "No",

    "Not Discussed is not applicable here as there is no mention of accreditation delays, however, the answer to whether there are any delays based on the content provided is: No": "No",

    "Not Discussed (However, considering the context is about a policy and a phone number with no answer, it might imply a delay or issue, but strictly speaking, delays in accreditation are not directly mentioned.)": "Not Discussed",

    "Not Discussed, however, I can infer that there might be a delay since it's been 27+ days with no call, so I will answer: Yes": "Yes",

    '"Not Discussed (However, since there is no information about accreditation delays, the most fitting answer from the options provided is ""No"")"': "No",

    "Not Discussed is not applicable here as there is no information about delays, so the answer should be: No": "No",

    '"Not Discussed (However, since the question requires a Yes/No answer, I\'ll provide ""No"" as there\'s no mention of delays)"': "No",

    "Not Discussed is not an option for this prompt, I will choose No as there is no mention of delays": "No",

    "Not Discussed is not an option here so I will default to No": "No",

    "Not Discussed but potentially yes as a reason for the AR call": "Yes",

    "Not Discussed is not an option here so the most suitable answer is No": "No"
}
emails["crm_delays_in_accreditation"] = emails["crm_delays_in_accreditation"].replace(mapping)

# %%
emails['crm_contractor_engagement'].unique()
# Out:
# <StringArray>
# [                                                                                                 'Yes',
#                                                                                                    'No',
#                                                                                         'Not Discussed',
#                                                                                               'Unknown',
#                                                                                ' the price is too high',
#                                    ' indicating dissatisfaction with the service or support provided."',
#                                                           ' indicating dissatisfaction with the cost."',
#                                                       ' which they claim to have requested last year."',
#                                                      '"" indicating dissatisfaction with the service."',
#                                                                  '"" making it not feasible to renew."',
#                                              '"" implying they do not wish to renew their membership."',
#                                ' and they have chosen to drop clients that require the certification."',
#                                           ' indicating uncertainty about continuing with the service."',
#  '"" which led to a discussion about a one-off saving and the value of the SafeContractor membership."',
#                          ' citing time constraints and difficulties in responding to multiple emails."',
#                                                      ' leading to frustration and a desire to cancel."',
#                                                             ' finding the cost and effort ridiculous."',
#                                                                           ' just asked for invoice""."',
#                                         '"" which led them to consider canceling their accreditation."',
#                                                                                                     '0',
#                                                     ' and they are unhappy with the no-refund policy."',
#                                                                                          ' saving time',
#                                                            ' threatening to look elsewhere next year."',
#                                                                                  ' irrelevant requests',
#                                                                     ' citing it's not the right time."',
#                                        '"" indicating dissatisfaction with their previous experience."',
#                                      ' implying they want to leave due to an automatic renewal issue."',
#       ' indicating a loss of interest in pursuing the accreditation process with the current company."',
#                                                ' implying a change in business structure or identity."']
# Length: 29, dtype: str

# %%
mapping = {
    "Yes": "Yes",
    "No": "No",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown",

    ' indicating dissatisfaction with the service or support provided."': "No",
    '"" indicating dissatisfaction with the service."': "No",
    '"" making it not feasible to renew."': "No",
    '"" implying they do not wish to renew their membership."': "No",
    ' indicating uncertainty about continuing with the service."': "No",
    ' and they have chosen to drop clients that require the certification."': "No",
    ' citing it\'s not the right time."': "No",
    ' implying they want to leave due to an automatic renewal issue."': "No",

    ' which they claim to have requested last year."': "Unknown",
    ' irrelevant requests': "Unknown"
}
emails["crm_contractor_engagement"] = (emails["crm_contractor_engagement"].map(mapping).fillna("Unknown"))

# %%
emails['crm_contractor_sentiment'].unique()
# Out:
# <StringArray>
# [                                                                'Neutral',
#                                                            'Not Discussed',
#                                                                'Satisfied',
#                                                             'Dissatisfied',
#                                                                  'Unknown',
#                                 ' and they are considering cancellation."',
#                                                                      'Yes',
#                                  'Initially Dissatisfied, later Satisfied',
#                                    'Initially Dissatisfied, later Neutral',
#  ' and believes the requests for qualifications and RAMS are ridiculous."',
#                                                 ' and protecting people."',
#                                ' and no work gained from the membership."',
#                                                                       'No']
# Length: 13, dtype: str

# %%
mapping = {
    "Satisfied": "Satisfied",
    "Neutral": "Neutral",
    "Dissatisfied": "Dissatisfied",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown",

    "Initially Dissatisfied, later Neutral": "Neutral",

    "Yes": "Dissatisfied",
    "No": "Dissatisfied",
    " and no work gained from the membership.\"": "Dissatisfied"
}

emails["crm_contractor_sentiment"] = (
    emails["crm_contractor_sentiment"]
    .map(mapping)
    .fillna("Unknown")
)

# %%
emails['crm_contractor_sentiment_score'].unique()
# Out:
# <StringArray>
# [           '50', 'Not Discussed',            '80',             '0',
#             '40',            '30',            '20',           '100',
#             '31',            '90',            '39',            '35',
#             '60',            '84',            '37',            '45',
#             '38',            '16',            '83',            '91',
#             '82',            '99',            '95',            '46',
#             '97',            '33',            '42',            '93',
#             '43',            '48',       'Unknown',            '70',
#             '27',            '25',           'Yes',  'Dissatisfied',
#             '36',            '55',            '41',            '10',
#        'Neutral',     'Satisfied',            '49',            '94',
#             '98',            '86',            '85',          '25.5',
#           '57.5',          '62.5',            '87',            '96',
#           '27.5']
# Length: 53, dtype: str

# %% [markdown]
# Handling datatypes

# %%
# convert to numeric
emails["crm_contractor_sentiment_score"] = pd.to_numeric(
    emails["crm_contractor_sentiment_score"], errors="coerce"
)

# convert to int
emails["crm_contractor_sentiment_score"] = (
    emails["crm_contractor_sentiment_score"]
    .fillna(-1)
    .astype(int)
)

# convert score category
def score_to_category(score):
    if score == -1:
        return "Unknown"
    elif score <= 40:
        return "Dissatisfied"
    elif score <= 60:
        return "Neutral"
    elif score <= 100:
        return "Satisfied"
    else:
        return "Unknown"

emails["sentiment_category"] = emails["crm_contractor_sentiment_score"].apply(score_to_category)
emails["crm_contractor_sentiment_score"] = emails["crm_contractor_sentiment_score"].apply(
    lambda x: "Unknown" if x == -1
    else "Dissatisfied" if x <= 40
    else "Neutral" if x <= 60
    else "Satisfied"
)

# preserve "Not Discussed" from original column
emails.loc[
    emails["crm_contractor_sentiment"] == "Not Discussed",
    "sentiment_category"
] = "Not Discussed"

# %%
emails['crm_dts_or_ssip_mentioned'].unique()
# Out:
# <StringArray>
# [           'No',           'Yes',       'Unknown',  'Dissatisfied',
#             '20',            '30',             '0',            '50',
#             '80', 'Not Discussed']
# Length: 10, dtype: str

# %%
emails["crm_dts_or_ssip_mentioned"] = emails["crm_dts_or_ssip_mentioned"].apply(
    lambda x: "Unknown" if pd.isna(x)
    else "Yes" if str(x).strip().lower() == "yes"
    else "Not Discussed" if str(x).strip().lower() == "not discussed"
    else "Unknown" if str(x).strip().lower() == "unknown"
    else "No"
)

# %%
emails['crm_customer_payment_intention'].unique()
# Out:
# <StringArray>
# ['No', 'Not Discussed', 'Yes', 'Unknown', '20', '0', '30']
# Length: 7, dtype: str

# %%
emails["crm_customer_payment_intention"] = emails["crm_customer_payment_intention"].replace({"0": "No"})

# %%
emails['crm_agent_chase_count'].unique()
# Out:
# <StringArray>
# [                                                                                                 '1',
#                                                                                                   '0',
#                                                                                                   '3',
#                                                                                                   '2',
#                                                                                                   '4',
#                                                                                                   '7',
#                                                                                                   '9',
#                                                                                                   '6',
#                                                                                                   '5',
#                                                                                                  '11',
#  ...
#                       '"Not specified, but mentioned as ""ever since"" which implies multiple times"',
#                                                      'Not specified, but multiple attempts were made',
#  '1 (The auditor made several attempts to reach the customer, but the exact number is not specified)',
#                                    'Not specified, but multiple attempts were made by the audit team',
#                                                                   'A few (no exact number specified)',
#                                                              'Several (no specific number mentioned)',
#                                                       'Multiple attempts, exact number not specified',
#                                                    'Multiple attempts (no specific number mentioned)',
#                                                             'Multiple (no specific number mentioned)',
#                                                             'A few times (no exact number specified)']
# Length: 113, dtype: str

# %%
emails["crm_agent_chase_count"].value_counts()
# Out:
# crm_agent_chase_count
# 0                                                   37199
# 1                                                   31223
# 2                                                   23726
# Unknown                                             11155
# 3                                                   10397
#                                                     ...
# Several (no specific number mentioned)                  1
# Multiple attempts, exact number not specified           1
# Multiple attempts (no specific number mentioned)        1
# Multiple (no specific number mentioned)                 1
# A few times (no exact number specified)                 1
# Name: count, Length: 113, dtype: int64

# %%
def map_chase_count(val):
    if pd.isna(val):
        return "Unknown"
    
    val = str(val).lower()

    # numeric
    try:
        num = int(val)
        if num <= 1:
            return "Low"
        elif num <= 4:
            return "Medium"
        else:
            return "High"
    except:
        pass

    # text mapping
    if "one" in val:
        return "Low"
    
    elif any(word in val for word in ["few", "several", "monthly", "every month"]):
        return "Medium"
    
    elif any(word in val for word in ["multiple", "many", "numerous", "more than", "8+", "quite a few"]):
        return "High"
    
    elif any(word in val for word in ["unknown", "not specified", "not discussed"]):
        return "Unknown"
    
    return "Unknown"


emails["crm_agent_chase_count"] = emails["crm_agent_chase_count"].apply(map_chase_count)

# %%
emails['crm_membership_overdue'].unique()
# Out:
# <StringArray>
# [                                                                                                          'Yes',
#                                                                                                  'Not Discussed',
#                                                                                                             'No',
#                                                         ' as a ""Deem to Satisfy"" for their CHAS accreditation',
#                                                                                    ' despite being up to date."',
#                                                 ' which they requested to be removed and the invoice reissued."',
#                                                                     ' and the manner in which it was executed."',
#                                                              ' preventing them from renewing their membership."',
#                                                                             ' which is not currently included."',
#                                                                           ' possibly because it was too early."',
#                                ' and the invoice amount not being reduced despite not conducting a full audit."',
#                                ' and also requested clarification on the renewal health and safety assessment."',
#                                                           ' which they claimed was damaging to their business."',
#                                                                                           ' indeed too busy""."',
#                                            ' citing that the questions did not apply to him as he works alone."',
#                                                ' leading to frustration and multiple calls to chase the audit."',
#                                                        '"" and was unhappy with the level of customer service."',
#                       ' and also had problems providing site-specific RAMS and evidence of refresher training."',
#                                           ' leading to pressure from clients threatening to withhold payments."',
#                               ' and also had to clarify some information for the Health and Safety Assessment."',
#                                         ' and expressed concern about the accreditation process taking too long',
#                                                                                        ' over-reliance on email',
#                                  ' and also had concerns with the alternative category ""Curtain Upholstery""."',
#                                  ' with all questions in part one greyed out and part two showing as complete."',
#                                                                   ' which don't provide formal qualifications."',
#                                                                                                        'Unknown',
#                                                                  ' your call cannot me connected at present""."',
#                                                                                       ' finding it misleading."',
#                                                            ' and also felt that they were missold the package."',
#                                    '"" and also experienced poor communication regarding part payment options."',
#                                                                                                   ' HS Direct."',
#  ' especially after a fatality incident where the membership meant nothing to the Health and Safety executive."',
#                                                                                           ' working in accounts',
#                                                                                                 'Almost expired',
#                                                                           ' which was later clarified as a typo',
#                                                                                 '"" and requested 1-1 support."',
#                         ' and also had to provide additional information for the Health and Safety Assessment."',
#                                                               ' and had discrepancies in their employee count."',
#                                 ' and was asked to contact Avetta to change the scope or opt for a full audit."',
#               ' and ""C02-02 Confined Spaces Pre-Entry Checklist.doc"" which was a checklist and not accepted."',
#                                                                      ' and had issues with irrelevant questions',
#                                   ' and also had to provide additional information such as site-specific RAMS."',
#                                                              ' and the agent had to submit it on their behalf."',
#                                                                 ' which was required for the audit to proceed."',
#                                             ' and also had trouble accessing and completing the questionnaire."',
#              ' and they were unsure how to access the portal and what documents were needed for accreditation."',
#                                                  ' which was not covered by their existing LRQA accreditation."',
#                           ' and also had to provide additional information for the Health and Safety Assessment',
#                                 ' and also had to provide additional information for the pre-audit assessment."',
#                                     ' and had to provide additional information for the accreditation process."',
#                                                                      '"" and needed assistance from the agent."',
#                                                                                        ' professional indemnity',
#                                      ' but was advised that it had saved and QS part 2 still needs completing."',
#                                                                                                              '0']
# Length: 54, dtype: str

# %%
emails["crm_membership_overdue"].value_counts()
# Out:
# crm_membership_overdue
# Not Discussed                                                                                                    54110
# Yes                                                                                                              30137
# No                                                                                                               27937
# Unknown                                                                                                          11155
#  as a ""Deem to Satisfy"" for their CHAS accreditation                                                               1
#  despite being up to date."                                                                                          1
#  which they requested to be removed and the invoice reissued."                                                       1
#  and the manner in which it was executed."                                                                           1
#  preventing them from renewing their membership."                                                                    1
#  which is not currently included."                                                                                   1
#  possibly because it was too early."                                                                                 1
#  and the invoice amount not being reduced despite not conducting a full audit."                                      1
#  and also requested clarification on the renewal health and safety assessment."                                      1
#  which they claimed was damaging to their business."                                                                 1
#  indeed too busy""."                                                                                                 1
#  citing that the questions did not apply to him as he works alone."                                                  1
#  leading to frustration and multiple calls to chase the audit."                                                      1
# "" and was unhappy with the level of customer service."                                                              1
#  and also had problems providing site-specific RAMS and evidence of refresher training."                             1
#  leading to pressure from clients threatening to withhold payments."                                                 1
#  and also had to clarify some information for the Health and Safety Assessment."                                     1
#  and expressed concern about the accreditation process taking too long                                               1
#  over-reliance on email                                                                                              1
#  and also had concerns with the alternative category ""Curtain Upholstery""."                                        1
#  with all questions in part one greyed out and part two showing as complete."                                        1
#  which don't provide formal qualifications."                                                                         1
#  your call cannot me connected at present""."                                                                        1
#  finding it misleading."                                                                                             1
#  and also felt that they were missold the package."                                                                  1
# "" and also experienced poor communication regarding part payment options."                                          1
#  HS Direct."                                                                                                         1
#  especially after a fatality incident where the membership meant nothing to the Health and Safety executive."        1
#  working in accounts                                                                                                 1
# Almost expired                                                                                                       1
#  which was later clarified as a typo                                                                                 1
# "" and requested 1-1 support."                                                                                       1
#  and also had to provide additional information for the Health and Safety Assessment."                               1
#  and had discrepancies in their employee count."                                                                     1
#  and was asked to contact Avetta to change the scope or opt for a full audit."                                       1
#  and ""C02-02 Confined Spaces Pre-Entry Checklist.doc"" which was a checklist and not accepted."                     1
#  and had issues with irrelevant questions                                                                            1
#  and also had to provide additional information such as site-specific RAMS."                                         1
#  and the agent had to submit it on their behalf."                                                                    1
#  which was required for the audit to proceed."                                                                       1
#  and also had trouble accessing and completing the questionnaire."                                                   1
#  and they were unsure how to access the portal and what documents were needed for accreditation."                    1
#  which was not covered by their existing LRQA accreditation."                                                        1
#  and also had to provide additional information for the Health and Safety Assessment                                 1
#  and also had to provide additional information for the pre-audit assessment."                                       1
#  and had to provide additional information for the accreditation process."                                           1
# "" and needed assistance from the agent."                                                                            1
#  professional indemnity                                                                                              1
#  but was advised that it had saved and QS part 2 still needs completing."                                            1
# 0                                                                                                                    1
# Name: count, dtype: int64

# %%
#values not matching predefined categories were treated as missing and imputed as “Unknown” to handle non-informative text
mapping = {
    "Yes": "Yes",
    "No": "No",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown"
}
emails["crm_membership_overdue"] = (
    emails["crm_membership_overdue"]
    .map(mapping)
    .fillna("Unknown")
)

# %%
to_drop = [ ' preventing them from renewing their membership."',
                                                                          ' possibly because it was too early."',
                                 ' with all questions in part one greyed out and part two showing as complete."',
                                                                                                  ' HS Direct."',
 ' especially after a fatality incident where the membership meant nothing to the Health and Safety executive."',
                                                                          ' which was later clarified as a typo',
                                                                                '"" and requested 1-1 support."',
              ' and ""C02-02 Confined Spaces Pre-Entry Checklist.doc"" which was a checklist and not accepted."',
                                                             ' and the agent had to submit it on their behalf."',
                                                                     '"" and needed assistance from the agent."']
emails = emails[~emails['crm_membership_overdue'].isin(to_drop)]

# %%
emails['crm_auto_renewal_status'].unique()
# Out:
# <StringArray>
# [                                                                              '0',
#                                                                                '2',
#                                                                                '1',
#                                 ' rendering their current accreditation invalid."',
#                                                                    'Not Discussed',
#                                                                               'No',
#                                                                              'Yes',
#                                                    ' potentially up to 8 months."',
#                                        ' and over-querying of supplied evidence."',
#                                                                          'Unknown',
#                                                ' and not being familiar with it."',
#  ' and also had to provide additional information for the accreditation process."',
#                                   ' but was helped to correct this by the agent."',
#   ' including evidence of face masks and Respiratory Protective Equipment (RPE)."',
#                                                      ' and employer's liability."']
# Length: 15, dtype: str

# %%
emails["crm_auto_renewal_status"].value_counts()
# Out:
# crm_auto_renewal_status
# 0                                                                                  105135
# Unknown                                                                             11155
# 2                                                                                    4702
# 1                                                                                    2348
# Not Discussed                                                                          20
# No                                                                                     14
# Yes                                                                                     7
#  rendering their current accreditation invalid."                                        1
#  potentially up to 8 months."                                                           1
#  and over-querying of supplied evidence."                                               1
#  and not being familiar with it."                                                       1
#  and also had to provide additional information for the accreditation process."         1
#  but was helped to correct this by the agent."                                          1
#  including evidence of face masks and Respiratory Protective Equipment (RPE)."          1
#  and employer's liability."                                                             1
# Name: count, dtype: int64

# %%
mapping = {
    "Yes": "Yes",
    "No": "No",
    "1": "Yes",
    "0": "No",
    "2": "Unknown",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown"
}

emails["crm_auto_renewal_status"] = (
    emails["crm_auto_renewal_status"]
    .map(mapping)
    .fillna("Unknown")
)

# %%
to_drop = ['and also had to provide additional information for the accreditation process."']
emails = emails[~emails['crm_auto_renewal_status'].isin(to_drop)]

# %%
emails['crm_dissatisified_with_renewal_price'].unique()
# Out:
# <StringArray>
# [                                                                        'No',
#                                                               'Not Discussed',
#                                                                         'Yes',
#                                                                           '0',
#                                                                           '2',
#                                                                     'Unknown',
#  'No actions or steps were taken by the agent in the provided email content.']
# Length: 7, dtype: str

# %%
mapping = {
    "Yes": "Yes",
    "No": "No",
    "1": "Yes",
    "0": "No",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown"
}

emails["crm_dissatisified_with_renewal_price"] = (
    emails["crm_dissatisified_with_renewal_price"]
    .map(mapping))

# %%
emails['crm_customer_complained'].unique()
# Out:
# <StringArray>
# [                                                                      'No',
#                                                                       'Yes',
#                                                                   'Unknown',
#                                                                  '[Yes/No]',
#                                                             'Not Discussed',
#                                'Not applicable (no email content provided)',
#                     'Not applicable (there is no email content to analyze)',
#                           'Not applicable (there is no content to analyze)',
#  'Not applicable (there is no call transcript or email content to analyze)',
#                                 'Not applicable (no conversation provided)',
#          'Not applicable (there is no call mentioned in the email content)',
#                     'Not applicable (there is no call transcript provided)',
#                                                            'Not Applicable',
#                  'Not Applicable (since there is no call content provided)',
#                              'Not applicable (no call transcript provided)']
# Length: 15, dtype: str

# %%
mapping = {
    "Yes": "Yes",
    "No": "No",
    "Not Discussed": "Not Discussed",
    "Unknown": "Unknown",
    "Not applicable (no email content provided)": "Not Applicable",
    "Not applicable (there is no content to analyze)": "Not Applicable",
    "Not applicable (there is no call transcript or email content to analyze)": "Not Applicable",
    "Not applicable (no conversation provided)": "Not Applicable",
    "Not applicable (there is no call mentioned in the email content)": "Not Applicable",
    "Not Applicable": "Not Applicable",
    "Not applicable (there is no call transcript provided)": "Not Applicable"
}

emails["crm_customer_complained"] = emails["crm_customer_complained"].map(mapping)

# %%
emails['crm_refund_mentioned'].unique()
# Out:
# <StringArray>
# [                                                                                    'Yes',
#                                                                                       'No',
#                                                                                  'Unknown',
#                                    ' feeling it implied their evidence was not legitimate',
#                                 ' which provides laundry services for top London hotels."',
#                                        ' which would dramatically affect their business."',
#                                          ' and the additional cost for expedited review."',
#                           ' despite their accreditation and insurances being up to date."',
#                                                      ' which the agent was not aware of."',
#      ' and also mentioned being overcharged and not receiving their certificate on time."',
#                        ' but the reason for their frustration was not explicitly stated."',
#  '"" with all questions on part one greyed out and part two already showing as complete."',
#                                                                      ' and then hung up."',
#                             ' but it was unclear if it was directed at the agent or not."',
#                                                            ' indicating dissatisfaction."',
#                                                    ' considering it ""highway robbery""."',
#                   ' and saw no value in membership since Homebase was no longer trading."',
#                                      ' which led to a client turning them down for work."',
#                                                                                 '[Yes/No]',
#       ' which they felt was unfair and potentially in breach of competition regulations."',
#                             ' completing window work without SafeContractor accreditation',
#                                 ' which they found unnecessarily severe and threatening."',
#                           ' making the renewal process pointless for their organization."',
#      '"" and also mentioned that they hadn't received a single lead from SafeContractor."',
#                                                                            'Not Discussed',
#                                               'Not applicable (no email content provided)',
#                                    'Not applicable (there is no email content to analyze)',
#                                                'Not applicable (no conversation provided)']
# Length: 28, dtype: str

# %%
def clean_refund_mentions(val):
    val_str = str(val).strip()
    
    #Check for "Not applicable" variations first
    if "not applicable" in val_str.lower():
        return "Not Applicable"
    map_to_yes=['but it was unclear if it was directed at the agent or not."',
                'considering it ""highway robbery""."',
                'and saw no value in membership since Homebase was no longer trading."',
                'making the renewal process pointless for their organization."']
    if any(variation in val_str for variation in map_to_yes):
        return "Yes"
    return val_str
emails['crm_refund_mentioned'] = emails['crm_refund_mentioned'].apply(clean_refund_mentions)

# %%
to_drop = ['""with all questions on part one greyed out and part two already showing as complete."']
emails = emails[~emails['crm_refund_mentioned'].isin(to_drop)]

# %%
emails['crm_negative_customer_experience'].unique()
# Out:
# <StringArray>
# [                                                  'Yes',
#                                                'Unknown',
#   ' and also expressed concerns about the audit process',
#                                                     'No',
#                                 '[Yes/No/Not Discussed]',
#                           ' causing them to lose work."',
#                                          'Not Discussed',
#             'Not applicable (no email content provided)',
#  'Not applicable (there is no email content to analyze)']
# Length: 9, dtype: str

# %%
to_drop = ['Not applicable (no email content provided)']
emails = emails[~emails['crm_negative_customer_experience'].isin(to_drop)]

# %%
emails['crm_dissatisfaction_with_support'].unique()
# Out:
# <StringArray>
# [                                                                                                                                                                                               'No',
#                                                                                                                                                                                                'Yes',
#                                                                                                                                                                                      'Not Discussed',
#                                                                                                                               ' indicating a negative experience due to personal or health issues."',
#                                                                                                                                               '"" which may impact their eligibility for projects."',
#                                                                                                                                                                                   ' invalid address',
#                                                                                                                            ' which led to a last-minute and urgent request to resolve the payment."',
#                                                                                                                                                                ' indicating a negative experience."',
#                                                                                                                                               ' indicating a negative experience with the process."',
#                                                                                                                                 ' indicating a negative experience with the accreditation process."',
#                                                                                                                                              '"" which hindered their ability to update documents."',
#                                                                                                                                                   ' indicating a sense of urgency and frustration."',
#                                                                                                                                                                   ' causing confusion and concern."',
#                                                                                                                                                                                            ' Nick."',
#                                                                                                                                                                                            'Unknown',
#                        'The Contractor had a negative experience with the assigned work activity not matching their business, leading to delays and discussions with the auditor and customer care.',
#  '"The Contractor experienced a negative customer experience due to an error in their accreditation status, which was incorrectly listed as ""consultant"" instead of ""construction contractor""."',
#                                             'The contractor experienced frustration and dissatisfaction with the process, feeling pressured and unhappy with the additional cost for faster review.',
#                                           'The contractor experienced a negative customer experience due to receiving an incorrect email about their insurance status, causing unnecessary concern.',
#                                               'The Contractor had a negative experience because their expectations for the call were not met, leading to frustration and the call being terminated.',
#                                                                 'The contractor experienced frustration due to the excessive information requested, overcharging, and delayed certificate delivery.',
#                                                                                                                                  ' and was unhappy about potentially having to pay for an upgrade."',
#                                                                                                                                                                            ' leading to lost work."',
#                                              'The Contractor had a negative experience due to frustration with the accreditation process, but the specifics of their frustration were not detailed.',
#                                                                                                    'The contractor experienced difficulties accessing the QA system, which hindered their progress.',
#                                                                                                                                       ' leading to an inaccurate and significantly increased cost."',
#                                                    'The Contractor had a negative experience when they received an unexpected or unwanted call, leading to an explicit outburst and abrupt hang-up.',
#                                                                                              'The Contractor had a negative experience during the initial call, which led to a awkward interaction.',
#                                                                                                                                                                   ' which may have caused concern."',
#                                                                                   '"The Contractor appeared to be dissatisfied, as evidenced by their request to ""shut it down"" during the call."',
#                                    'The Contractor had a negative experience due to the unexpected and substantial price increase, which they felt was unfair and unsustainable for their business.',
#                                                                         'The contractor had a negative experience due to the unexpected cost increase and feeling misled about the price stability.',
#                                                                                                                                                          ' indicating a potential financial issue."',
#                                                                                                                                                  ' indicating a negative experience with a client."',
#                                                                                                                                 ' indicating dissatisfaction with the accreditation/audit process."',
#                                                                                                                                     ' indicating a lack of value in the SafeContractor membership."',
#                                                                                                                                                              '"" indicating a negative experience."',
#                                                                                                                                                            ' causing delay in their accreditation."',
#                                                                                                                                                     ' indicating a sense of urgency and annoyance."',
#                                                                                                                                       ' feeling that it adds costs without providing new services."',
#                                                                                                                                                                                    ' ill do it soon',
#                                                                  'Contractor experienced frustration due to the delay in resolving the issue with their certificate, which affected their business.',
#                                                                                                                                                                             '[Yes/No/Not Discussed]',
#         'The Contractor expressed frustration and dissatisfaction with the new pricing model, feeling that it would disproportionately affect their business and limit their visibility to clients.',
#                                                                                                                                                        ' which may indicate a negative experience."',
#                                                                                                                                              ' but it was resolved with assistance from the agent."',
#                                                                                                                                     ' indicating a potential issue with the accreditation process."',
#                                                                                                                                                     ' suggesting it implies a non-gentle reminder."',
#                                                                                                                                                    ' stating it should be renamed as it is a health',
#                       'The contractor had a negative experience due to the tone of the email and the request for renewal payment despite their current certificate being valid until 9th July 2025.',
#                               'The Contractor had a negative experience due to unfulfilled promises and inability to achieve accreditation, rendering the process pointless for their organization.',
#                                                                       'The contractor had a negative experience due to the significant price increase and lack of leads provided by SafeContractor.',
#                                                                                                                                                       ' indicating a negative customer experience."',
#                                                                                                                                                                  '"" and being busy with ISO work."',
#                                                                                                                                                     '"" indicating a potential financial struggle."',
#                                                                                                                                              ' indicating a struggle with managing their workload."',
#                                                                                                                                              'Not applicable (there is no email content to analyze)']
# Length: 57, dtype: str

# %%
def clean_refund_mentions(val):
    val_str = str(val).strip()
    
    #Check for variations 
    variations=["negative experience","negative customer experience"] 
    if any(variation in val_str.lower() for variation in variations):
        return "Yes"
    
    return val_str
emails['crm_dissatisfaction_with_support'] = emails['crm_dissatisfaction_with_support'].apply(clean_refund_mentions)

# %%
to_drop = ['Nick."','"" which hindered their ability to update documents."']
emails = emails[~emails['crm_dissatisfaction_with_support'].isin(to_drop)]

# %%
emails['crm_financial_hardship_mentioned'].unique()
# Out:
# <StringArray>
# [                                                                                                                                         'Yes',
#                                                                                                                                 'Not Discussed',
#                                                                                                                                            'No',
#                                                                                                                 ' city is required"" message."',
#                                                                                                                                       'Unknown',
#                                                                                                                                      ' bye""."',
#                                                                                                                        '[Yes/No/Not Discussed]',
#  '"The Contractor expressed frustration due to the issue with ""24 hour locksmiths"" and the inconvenience with the payment link not working."',
#                                                                                                                                       ' safety',
#                                                                                                                                          'Yes ',
#                                                                                         'Not applicable (there is no email content to analyze)']
# Length: 11, dtype: str

# %%
to_drop = [' bye""."', 'Not applicable (no email content provided)']
emails = emails[~emails['crm_financial_hardship_mentioned'].isin(to_drop)]

# %%
emails['crm_membership_level'].value_counts()
# Out:
# crm_membership_level
# In progress                                                       45217
# Accredited                                                        35847
# Not Discussed                                                     29889
# Unknown                                                           11155
# Members only                                                        854
# Standard                                                            162
# Not Accredited                                                      104
# In Progress                                                          23
# Silver                                                               17
# Gold                                                                 13
# Premier                                                              10
# Standard membership level                                             9
# Membership (Standard)                                                 8
# Accredited (Gold level)                                               7
# Standard membership                                                   6
# Bronze                                                                5
# Express                                                               4
# Gold level                                                            3
# Accredited at Silver level                                            3
# Accredited (Silver level)                                             3
# Premier Band B                                                        2
# Band C1 (5-9 employees)                                               2
# Membership (Premier)                                                  2
# Premier package                                                       2
# Accredited (Bronze level)                                             2
# Silver level                                                          2
# Member Only                                                           2
# Express membership level                                              2
# Premier services                                                      1
# Group Membership                                                      1
# Premier Band C2                                                       1
# Base membership                                                       1
# Standard Band B                                                       1
# Assisted Band C1                                                      1
# Membership (PREMIER)                                                  1
# Band B                                                                1
# Premier Band E                                                        1
# Standard membership level (upgraded to Express)                       1
# Accredited at the Gold level                                          1
# Accredited (SUSPENDED)                                                1
# Premier Band D                                                        1
# Standard level of membership                                          1
# Accredited at Gold level                                              1
# Accredited (Silver level, later upgraded to Gold)                     1
# Accredited at Bronze level                                            1
# Premier package £704 + VAT                                            1
# Accredited (Gold)                                                     1
# Membership Only                                                       1
# Accredited (Gold level OBC)                                           1
# Verified at Gold                                                      1
# Renewal Complete                                                      1
# Standard package                                                      1
# Band D (15-29 employees)                                              1
# Prem                                                                  1
# Accredited (implied by the context, but not explicitly stated)        1
# Standard Membership                                                   1
# Standard-Safe contractor Membership                                   1
# Existing member                                                       1
# Name: count, dtype: int64

# %%
#mapping for "Standard" and "Accredited" groups
membership_mapping = {
    "Standard membership level": "Standard",
    "Standard Membership": "Standard",
    "Standard package": "Standard",
    "Accredited (Silver level)": "Accredited"
}
emails['crm_membership_level'] = emails['crm_membership_level'].replace(membership_mapping)
print(emails['crm_membership_level'].value_counts())
# Out:
# crm_membership_level
# In progress                                                       45217
# Accredited                                                        35850
# Not Discussed                                                     29889
# Unknown                                                           11155
# Members only                                                        854
# Standard                                                            173
# Not Accredited                                                      104
# In Progress                                                          23
# Silver                                                               17
# Gold                                                                 13
# Premier                                                              10
# Membership (Standard)                                                 8
# Accredited (Gold level)                                               7
# Standard membership                                                   6
# Bronze                                                                5
# Express                                                               4
# Gold level                                                            3
# Accredited at Silver level                                            3
# Premier Band B                                                        2
# Band C1 (5-9 employees)                                               2
# Membership (Premier)                                                  2
# Premier package                                                       2
# Accredited (Bronze level)                                             2
# Silver level                                                          2
# Member Only                                                           2
# Express membership level                                              2
# Premier services                                                      1
# Group Membership                                                      1
# Premier Band C2                                                       1
# Base membership                                                       1
# Standard Band B                                                       1
# Assisted Band C1                                                      1
# Membership (PREMIER)                                                  1
# Band B                                                                1
# Premier Band E                                                        1
# Standard membership level (upgraded to Express)                       1
# Accredited at the Gold level                                          1
# Accredited (SUSPENDED)                                                1
# Premier Band D                                                        1
# Standard level of membership                                          1
# Accredited at Gold level                                              1
# Accredited (Silver level, later upgraded to Gold)                     1
# Accredited at Bronze level                                            1
# Premier package £704 + VAT                                            1
# Accredited (Gold)                                                     1
# Membership Only                                                       1
# Accredited (Gold level OBC)                                           1
# Verified at Gold                                                      1
# Renewal Complete                                                      1
# Band D (15-29 employees)                                              1
# Prem                                                                  1
# Accredited (implied by the context, but not explicitly stated)        1
# Standard-Safe contractor Membership                                   1
# Existing member                                                       1
# Name: count, dtype: int64

# %%
emails.isnull().sum()[emails.isnull().sum() > 0]
# Out:
# crm_dissatisified_with_renewal_price    3
# crm_customer_complained                 4
# dtype: int64

# %% [markdown]
# Saving cleaned dataset

# %%
import os
os.makedirs('../../data/cleaned', exist_ok=True)
emails.to_csv('../../data/cleaned/emails_cleaned.csv', index=False)
print('Saved! Shape:', emails.shape)
# Out:
# Saved! Shape: (123385, 26)
