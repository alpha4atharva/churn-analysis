# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
cc_calls = pd.read_csv('../../data/raw/cc_calls.csv', low_memory=False)
cc_calls.columns = cc_calls.columns.str.lower().str.replace(' ', '_')
cc_calls.shape
# Out:
# (32882, 33)

# %% [markdown]
# Dropping duplicate rows

# %%
cc_calls['cc_care_package'].unique()
# Out:
# array(['Standard', 'Premier', 'Express', 'Assisted', 'Not Discussed',
#        'Print', 'Assisted (currently), Standard (requested)',
#        'Assisted/Standard', 'Assistive', 'Sister Package',
#        'Faster package', 'Off-Stander',
#        'Funder Package (initially), then Express (upgraded)',
#        'Standard/Premier', 'Fast Track', nan, 'Family', 'Primary',
#        'Stamp', 'Standards', 'Assisted Package',
#        '[Standard/Premier/Express/Not Discussed]',
#        'Not Discussed, but upgrading to Premier was discussed',
#        'Express, then changed to Standard', 'Premium', 'Seller', 'FAFSA',
#        '20 working day package', 'FANDA', 'Clickers package', 'Address',
#        'Press Package', 'Rest', 'Sender', 'Fastest', 'Family Package',
#        'Excess', 'Gold', 'SAM',
#        'Not Discussed, but later discussed as Express', 'Slander',
#        'Class', 'Start-up package', 'Stanford', 'Assist',
#        'Not Discussed, but later upgraded to Express',
#        'Not Discussed (initially on Standard, but upgraded)',
#        'Premier/Express', 'Fast', 'Assistance', 'Fastest package',
#        'Express, later changed to Standard', 'Assisted Membership',
#        'Thunder', 'Stamp package', 'Sponsored membership',
#        'Assisted Audit', 'Unassisted'], dtype=object)

# %%
cc_calls.duplicated().sum()
# Out:
# np.int64(93)

# %%
cc_calls = cc_calls.drop_duplicates()
cc_calls.shape
# Out:
# (32789, 33)

# %% [markdown]
# Dropping rows with null co_ref

# %%
cc_calls['co_ref'].isnull().sum()
# Out:
# np.int64(1153)

# %%
cc_calls = cc_calls.dropna(subset=['co_ref'])
cc_calls.shape
# Out:
# (31636, 33)

# %% [markdown]
# Standardizing values in direction column

# %%
cc_calls['direction'].value_counts()
# Out:
# direction
# OUT_BOUND    24292
# IN_BOUND      7344
# Name: count, dtype: int64

# %%
cc_calls['direction'] = cc_calls['direction'].replace({
    'OUT_BOUND': 'Outbound',
    'IN_BOUND': 'Inbound'
})
cc_calls['direction'].value_counts()
# Out:
# direction
# Outbound    24292
# Inbound      7344
# Name: count, dtype: int64

# %% [markdown]
# Converting proper datatype of dates

# %%
cc_calls['call_date'].head()
# Out:
# 0    08-05-2025
# 1    25-11-2024
# 2    23-10-2024
# 3    13-01-2025
# 4    19-03-2025
# Name: call_date, dtype: object

# %%
cc_calls['call_date'] = pd.to_datetime(cc_calls['call_date'], format='%d-%m-%Y')
cc_calls['call_date'].head()
# Out:
# 0   2025-05-08
# 1   2024-11-25
# 2   2024-10-23
# 3   2025-01-13
# 4   2025-03-19
# Name: call_date, dtype: datetime64[ns]

# %% [markdown]
# Handling score columns

# %%
score_columns = [
    'cc_contractor_sentiment_start_score', 
    'cc_contractor_sentiment_end_score', 
    'cc_contractor_sentiment_overall_score', 
    'cc_contractor_sentiment_issues_score'
]
cc_calls[score_columns].dtypes
# Out:
# cc_contractor_sentiment_start_score      object
# cc_contractor_sentiment_end_score        object
# cc_contractor_sentiment_overall_score    object
# cc_contractor_sentiment_issues_score     object
# dtype: object

# %%
for col in score_columns:
    cc_calls[col] = pd.to_numeric(cc_calls[col], errors='coerce')
cc_calls[score_columns].dtypes
# Out:
# cc_contractor_sentiment_start_score      float64
# cc_contractor_sentiment_end_score        float64
# cc_contractor_sentiment_overall_score    float64
# cc_contractor_sentiment_issues_score     float64
# dtype: object

# %% [markdown]
# Dropping irrelevant columns<br>
# 1- analysed_call -> has only one unique value<br>
# 2- call_year -> can be derived from call_date<br>
# 3- contact_id -> is unique identifier so wont be used for prediction

# %%
cc_calls['analysed_call'].unique()
# Out:
# array([1])

# %%
cc_calls['call_year'].unique()
# Out:
# array([2025, 2024, 2026])

# %%
cc_calls['contact_id'].nunique()
# Out:
# 494

# %%
cc_calls = cc_calls.drop(columns=['analysed_call', 'call_year', 'contact_id'])
cc_calls.shape
# Out:
# (31636, 30)

# %% [markdown]
# Handling columns with bad values

# %%
cc_calls['cc_care_package'].value_counts()
# Out:
# cc_care_package
# Not Discussed                                            24766
# Standard                                                  3617
# Express                                                   2494
# Premier                                                    420
# Assisted                                                   119
# [Standard/Premier/Express/Not Discussed]                    23
# Primary                                                      6
# Standards                                                    4
# Fast Track                                                   3
# Fastest package                                              2
# Stamp                                                        2
# Thunder                                                      1
# Start-up package                                             1
# Family Package                                               1
# Excess                                                       1
# Gold                                                         1
# Sponsored membership                                         1
# SAM                                                          1
# Not Discussed, but later discussed as Express                1
# Slander                                                      1
# Class                                                        1
# Assist                                                       1
# Stanford                                                     1
# Stamp package                                                1
# Assisted Membership                                          1
# Sender                                                       1
# Not Discussed, but later upgraded to Express                 1
# Not Discussed (initially on Standard, but upgraded)          1
# Premier/Express                                              1
# Fast                                                         1
# Express, later changed to Standard                           1
# Fastest                                                      1
# FANDA                                                        1
# Rest                                                         1
# Press Package                                                1
# Print                                                        1
# Assisted (currently), Standard (requested)                   1
# Assisted/Standard                                            1
# Assistive                                                    1
# Sister Package                                               1
# Faster package                                               1
# Off-Stander                                                  1
# Funder Package (initially), then Express (upgraded)          1
# Standard/Premier                                             1
# Family                                                       1
# Assisted Package                                             1
# Not Discussed, but upgrading to Premier was discussed        1
# Express, then changed to Standard                            1
# Premium                                                      1
# Seller                                                       1
# FAFSA                                                        1
# 20 working day package                                       1
# Clickers package                                             1
# Address                                                      1
# Unassisted                                                   1
# Name: count, dtype: int64

# %%
def normalize_package(x):
    if pd.isna(x):
        return "Unknown"
    
    x = str(x).lower()

    if "not discussed" in x:
        return "Not Discussed"

    if "express" in x or "fast" in x:
        return "Express"

    if "premier" in x or "premium" in x:
        return "Premier"
    
    if "standard" in x or "standards" in x:
        return "Standard"
    
    if "assist" in x:
        return "Assisted"
    
    return "Other"

cc_calls["cc_care_package"] = cc_calls["cc_care_package"].apply(normalize_package)

# %%
cc_calls['cc_care_package'].value_counts()
# Out:
# cc_care_package
# Not Discussed    24793
# Standard          3623
# Express           2506
# Premier            422
# Unknown            136
# Assisted           124
# Other               32
# Name: count, dtype: int64

# %%
cc_calls['cc_call_initiated_by'].value_counts()
# Out:
# cc_call_initiated_by
# Customer                         21550
# Agent                             8320
# Not Relevant                      1584
# [Agent/Customer/Not Relevant]       23
# No                                  22
# Not Applicable                       1
# Name: count, dtype: int64

# %%
valid_initiated = ['Customer', 'Agent', 'Not Relevant']
mode_val = cc_calls['cc_call_initiated_by'].mode()[0]
cc_calls['cc_call_initiated_by'] = cc_calls['cc_call_initiated_by'].where(cc_calls['cc_call_initiated_by'].isin(valid_initiated), other=mode_val)
cc_calls['cc_call_initiated_by'].value_counts()
# Out:
# cc_call_initiated_by
# Customer        21732
# Agent            8320
# Not Relevant     1584
# Name: count, dtype: int64

# %%
cc_calls['cc_contractor_sentiment'].value_counts()
# Out:
# cc_contractor_sentiment
# Satisfied                                                                                                                                                                               15627
# Neutral                                                                                                                                                                                 12595
# Not Discussed                                                                                                                                                                            2330
# Dissatisfied                                                                                                                                                                              930
#  Chris                                                                                                                                                                                      4
#  can you hear me?"""                                                                                                                                                                        3
# Neutral/Dissatisfied                                                                                                                                                                        3
#  Owen                                                                                                                                                                                       2
#  Carly                                                                                                                                                                                      1
#  which could simplify the accreditation process."                                                                                                                                           1
#  as well as the New Building Safety Act section. The agent provided clarification and assistance."                                                                                          1
#  despite having renewed their membership and uploaded insurance documents."                                                                                                                 1
#  despite having provided the necessary information."                                                                                                                                        1
#  Jess                                                                                                                                                                                       1
#  and the agent assisted him with the upgrade and arranged for the audit team to contact him regarding the principal contractor addition."                                                   1
#  despite having up-to-date insurance documents. The agent helped resolve the issue by manually updating the insurance information."                                                         1
#  explaining the necessary steps and potential costs."                                                                                                                                       1
#  which was caused by a payment issue that was already resolved."                                                                                                                            1
#  Holly                                                                                                                                                                                      1
#  Rebecca                                                                                                                                                                                    1
#  reducing the required documentation."                                                                                                                                                      1
#  and the agent                                                                                                                                                                              1
#  which the agent helped resolve by explaining that it was likely due to their insurance expiration date."                                                                                   1
#  and the agent eventually responded with ""Can you hear me?"""                                                                                                                              1
#  and the agent assisted her in resolving the issue."                                                                                                                                        1
#  and to resolve an issue with accessing the questionnaire."                                                                                                                                 1
#  despite having notified Safe Contractor that they would not be renewing their membership."                                                                                                 1
# "" to their accreditation certificate                                                                                                                                                       1
#  and the agent helped him resolve the issue."                                                                                                                                               1
#  but was informed that it had expired and needed to be reinstated separately."                                                                                                              1
#  but the certificate doesn't reflect this change. The agent                                                                                                                                 1
#  indicating a potential connection issue."                                                                                                                                                  1
#  which was supposed to be included in their public liability insurance."                                                                                                                    1
#  but there is no response or engagement from the agent."                                                                                                                                    1
#  without any further context or discussion."                                                                                                                                                1
#  indicating a potential connection issue or the start of the call."                                                                                                                         1
#  let's go"" twice without any clear topic or issue being discussed."                                                                                                                        1
#  but there is no response or further conversation."                                                                                                                                         1
#  come on."""                                                                                                                                                                                1
#  but there is no further conversation to analyze."                                                                                                                                          1
#  and no further dialogue or context is provided."                                                                                                                                           1
#  indicating a potential connection issue or a call that was not fully initiated."                                                                                                           1
#  indicating a possible connection issue or a dropped call."                                                                                                                                 1
#  which couldn't be used for another approval."                                                                                                                                              1
#  and the agent helped her understand the next steps."                                                                                                                                       1
#  and the agent explained that the company only requires a copy of the customer's existing insurance for their records."                                                                     1
#  Julian                                                                                                                                                                                     1
#  which the agent explained and clarified that his membership fee includes the accreditation. The agent then transferred Anthony to the renewal team to confirm the payment details."        1
#  and the agent assisted him with the request and offered additional help."                                                                                                                  1
#  and then confirming if the agent could hear them."                                                                                                                                         1
#  and the agent offered to investigate and resolve the issue."                                                                                                                               1
#  and the agent assisted her with the process."                                                                                                                                              1
#  what the hell? No?"""                                                                                                                                                                      1
#  despite having updated their documents. The agent helped resolve the issue and confirmed that everything was up-to-date on their end."                                                     1
#  and the agent helped him troubleshoot the issue. The customer had completed all necessary steps but was still blocked                                                                      1
# Name: count, dtype: int64

# %%
valid_sentiments = ['Satisfied', 'Neutral', 'Dissatisfied', 'Not Discussed']
mode_val = cc_calls['cc_contractor_sentiment'].mode()[0]
cc_calls['cc_contractor_sentiment'] = cc_calls['cc_contractor_sentiment'].where(cc_calls['cc_contractor_sentiment'].isin(valid_sentiments), other=mode_val)
cc_calls['cc_contractor_sentiment'].value_counts()
# Out:
# cc_contractor_sentiment
# Satisfied        15781
# Neutral          12595
# Not Discussed     2330
# Dissatisfied       930
# Name: count, dtype: int64

# %% [markdown]
# Handling columns that should only contain Yes or No

# %%
yes_no_columns = [
    'cc_care_package_discussed', 'cc_urgency_getting_on_site',
    'cc_external_consultant', 'cc_agent_cross_sell_attempt',
    'cc_customer_issues_concerns', 'cc_business_struggles_financial_hardship',
    'cc_questionnaire_completion', 'cc_chasing_response',
    'cc_issues_within_questionnaire', 'cc_login_issues',
    'cc_platform_issues', 'cc_dissatisfaction_time_to_complete',
    'cc_process_complexity_concerns', 'cc_questions_harder_than_expected',
    'cc_dissatisfaction_support', 'cc_pricing_mentioned',
    'cc_pricing_sentiment_impact', 'cc_refund_discussed',
    'cc_contractor_suggest_leave', 'cc_contractor_complained'
]

for col in yes_no_columns:
    print(f"  {col}: {cc_calls[col].nunique()}")
# Out:
#   cc_care_package_discussed: 3
#   cc_urgency_getting_on_site: 3
#   cc_external_consultant: 3
#   cc_agent_cross_sell_attempt: 23
#   cc_customer_issues_concerns: 9
#   cc_business_struggles_financial_hardship: 6
#   cc_questionnaire_completion: 3
#   cc_chasing_response: 169
#   cc_issues_within_questionnaire: 58
#   cc_login_issues: 12
#   cc_platform_issues: 4
#   cc_dissatisfaction_time_to_complete: 3
#   cc_process_complexity_concerns: 24
#   cc_questions_harder_than_expected: 7
#   cc_dissatisfaction_support: 4
#   cc_pricing_mentioned: 11
#   cc_pricing_sentiment_impact: 8
#   cc_refund_discussed: 5
#   cc_contractor_suggest_leave: 64
#   cc_contractor_complained: 15

# %%
for col in yes_no_columns:
    mode_val = cc_calls[col].mode()[0]
    print(cc_calls[col].value_counts())
    print(f"Mode = {mode_val}")
    print()
# Out:
# cc_care_package_discussed
# No          24668
# Yes          6809
# [Yes/No]       23
# Name: count, dtype: int64
# Mode = No
#
# cc_urgency_getting_on_site
# No          28285
# Yes          3192
# [Yes/No]       23
# Name: count, dtype: int64
# Mode = No
#
# cc_external_consultant
# No          28110
# Yes          3367
# [Yes/No]       23
# Name: count, dtype: int64
# Mode = No
#
# cc_agent_cross_sell_attempt
# No                                                                                                 30304
# Yes                                                                                                 1153
# [Yes/No]                                                                                              23
#  which is a shortened process for accreditation."                                                      1
# "" who helps with the accreditation process                                                            1
#  supports with risk assessments and other safety-related tasks."                                       1
# "" who deals with the accreditation process                                                            1
#  implying they have some external support                                                              1
#  he's all about                                                                                        1
#  implying they have external support or a team that helps with the accreditation process."             1
# "" is helping with the accreditation process."                                                         1
#  helps review the health and safety questionnaire."                                                    1
#  implying that an external consultant or someone else has helped with the accreditation process        1
#  supports with all of the customer's health and safety needs."                                         1
#  but the agent needs to chase him to get it done."                                                     1
# "" helps with the accreditation process                                                                1
#  supports with health and safety certificates and possibly other related services."                    1
#  implying that the external consultant or team will help with completing the questionnaire."           1
#  she's a contractor."""                                                                                1
#  helps with the accreditation process                                                                  1
#  indicating that they have external support or accreditation."                                         1
#  helps them with audits and possibly other accreditation processes."                                   1
# "" helps with documents and the accreditation process."                                                1
# Name: count, dtype: int64
# Mode = No
#
# cc_customer_issues_concerns
# No                                                                                                                                                                                28248
# Yes                                                                                                                                                                                3212
# [Yes/No]                                                                                                                                                                             23
# Not Applicable                                                                                                                                                                       12
# The agent mentioned their health and safety consultancy, Safe Workforce, in response to the customer's mention of a consultancy, but did not explicitly attempt to cross-sell.        1
#  implying that they have external support for the questionnaire."                                                                                                                     1
#  LED displays                                                                                                                                                                         1
#  which is a different product."                                                                                                                                                       1
#  HR workforce thing""                                                                                                                                                                 1
# Name: count, dtype: int64
# Mode = No
#
# cc_business_struggles_financial_hardship
# No                                                                                                        30530
# Yes                                                                                                         939
# [Yes/No]                                                                                                     23
# Not Applicable                                                                                                6
#  or a complete"" offering from Scanlight."                                                                    1
#  implying that they have an external HR system that is compatible with SafeContractor's requirements."        1
# Name: count, dtype: int64
# Mode = No
#
# cc_questionnaire_completion
# No          25383
# Yes          6210
# [Yes/No]       11
# Name: count, dtype: int64
# Mode = No
#
# cc_chasing_response
# No                                                                                                                            23847
# Yes                                                                                                                            7574
# [Yes/No]                                                                                                                         11
#  but did not specify any particular issues."                                                                                      3
#  indicating some level of difficulty or frustration."                                                                             2
#                                                                                                                               ...
#  implying they are too busy."                                                                                                     1
#  and was unable to submit their questionnaire due to incomplete health and safety management and qualification trainings."        1
#  really well"" and only took ""a couple of weeks                                                                                  1
#  implying some difficulty                                                                                                         1
#  despite having a valid SAFE contractor certificate."                                                                             1
# Name: count, Length: 169, dtype: int64
# Mode = No
#
# cc_issues_within_questionnaire
# No                                                                                           26213
# Yes                                                                                           4139
# Not mentioned                                                                                  384
# Not applicable                                                                                 285
# Not Applicable                                                                                  56
# [Yes/No]                                                                                        11
# Not mentioned in the conversation                                                               10
# Not applicable as there were no issues mentioned                                                 9
# Not applicable as no issues were mentioned                                                       8
# Not applicable to this scenario                                                                  8
# Not required                                                                                     7
# Not mentioned in the transcript                                                                  5
# Not applicable as there were no issues                                                           4
# Not applicable as there are no issues mentioned                                                  3
# Not applicable to this conversation                                                              3
# Not required as Prompt 1 is No                                                                   2
# Not applicable as the customer didn't mention any issues with the questionnaire content          2
# Not applicable as there were no issues with the questionnaire                                    2
# Not enough information                                                                           2
# Not applicable as there were no issues with the questionnaire content                            2
# Not applicable to this prompt as the answer to prompt 1 is No                                    1
# Not applicable as the customer didn't have issues with the questionnaire content                 1
#  indicating some level of frustration                                                            1
#  and also mentioned that filling it in is ""not the most exciting job in the world."""           1
#  was needed."                                                                                    1
#  but this is not an issue with completing the questionnaire itself."                             1
#  and ""health and safety management""."                                                          1
#  going on holiday for two weeks                                                                  1
# Not applicable to this prompt                                                                    1
# Not applicable as there are no issues mentioned.                                                 1
# Not applicable to the conversation                                                               1
# Not applicable as the customer did not have issues with the questionnaire                        1
# Not applicable as there is no issue with the questionnaire content                               1
# Not required as prompt 1 is No                                                                   1
#  which was not completed correctly."                                                             1
#  long job"" that gets rejected multiple times for filling out                                    1
#  due to being in the renewal process                                                             1
#  CBRE."                                                                                          1
#  just five minutes"" with some uploading and a reminder."                                        1
#  Chas                                                                                            1
#  although they couldn't identify what was missing."                                              1
#  including timing out and password issues."                                                      1
#  making the questions irrelevant."                                                               1
# Not applicable as the customer did not mention any issues with the questionnaire content.        1
# Not applicable as there were no issues mentioned with the content of the questionnaire.          1
#  deemed to satisfy"" and is waiting on them                                                      1
#  receiving only sales calls instead of help."                                                    1
#  but no specific issues were raised."                                                            1
#  and had a couple of last documents to upload before submitting."                                1
# Not applicable to this prompt as the answer to Prompt 1 is No                                    1
#  as they didn't understand what was being asked of them."                                        1
# Not applicable as the customer didn't have issues with the questionnaire                         1
# Not applicable as per prompt 1                                                                   1
#  and they haven't received any communication from the company after making a payment."           1
# Not applicable as the customer did not mention any issues with the questionnaire content         1
#  competencies                                                                                    1
#  I think                                                                                         1
#  and they need to upgrade it to a subcontractor level."                                          1
# Name: count, dtype: int64
# Mode = No
#
# cc_login_issues
# No                                                                                                                         29996
# Yes                                                                                                                         1587
# [Yes/No]                                                                                                                      11
# "" but the specific issue is not explicitly stated."                                                                           1
#  despite still being active and not expired."                                                                                  1
#  and other personal information                                                                                                1
#  and are frustrated with the amount of documentation required for a small company."                                            1
#  but this is not an issue with completing the questionnaire."                                                                  1
# Initially, yes, the customer was unsure if they had access to the portal, but they were able to log in during the call.        1
#  and that nothing changes year to year."                                                                                       1
#  but not a significant issue."                                                                                                 1
#  which caused a delay in completing the questionnaire."                                                                        1
# Name: count, dtype: int64
# Mode = No
#
# cc_platform_issues
# No                                           29432
# Yes                                           2159
# [Yes/No]                                        11
#  which they believe is a breach of GDPR."        1
# Name: count, dtype: int64
# Mode = No
#
# cc_dissatisfaction_time_to_complete
# No          30199
# Yes          1393
# [Yes/No]       11
# Name: count, dtype: int64
# Mode = No
#
# cc_process_complexity_concerns
# No                                                                                                                                                                                                                                                                  28470
# Yes                                                                                                                                                                                                                                                                  3092
# [Yes/No]                                                                                                                                                                                                                                                               11
# Not applicable                                                                                                                                                                                                                                                          3
# No information                                                                                                                                                                                                                                                          3
#  but no specific dissatisfaction was mentioned."                                                                                                                                                                                                                        1
#  which could imply some level of time constraint or difficulty in dedicating time to the questionnaire."                                                                                                                                                                1
# Not Applicable                                                                                                                                                                                                                                                          1
#  indicating frustration with the delay."                                                                                                                                                                                                                                1
#  quite a lot of work to put into it."""                                                                                                                                                                                                                                 1
# "" suggesting that they find it somewhat bothersome or tedious."                                                                                                                                                                                                        1
#  indicating frustration with the time it takes to complete it."                                                                                                                                                                                                         1
#  implying they were feeling rushed and possibly frustrated with the time constraint."                                                                                                                                                                                   1
#  implying dissatisfaction with the time it took to complete the questionnaire."                                                                                                                                                                                         1
# "The customer expressed frustration with the frequency of the questionnaire, stating they ""barely do these annual reviews every six months                                                                                                                             1
# The customer expressed that they needed more time to complete the questionnaire, but this was resolved when the agent explained that the portal is open all year round and they can submit 30 days before their current certificate expires.                            1
#  which they had experienced before."                                                                                                                                                                                                                                    1
# Not applicable to this prompt as the customer did not express dissatisfaction with the time taken to complete the questionnaire.                                                                                                                                        1
# The customer did not express any dissatisfaction with the time it took to complete the questionnaire.                                                                                                                                                                   1
# The customer expressed frustration that what should take a few hours ends up taking months due to the need for clarification and renewal of answers.                                                                                                                    1
# The customer expressed frustration with the lengthy and complicated process, stating it should be easier and quicker, and that they've had better experiences in the past with more helpful consultants.                                                                1
#  despite having submitted all required documents."                                                                                                                                                                                                                      1
# The customer has expressed dissatisfaction with the length of time it has taken to complete the questionnaire, mentioning that their accreditation lapsed nearly two years ago and they have had multiple conversations with representatives without resolution.        1
#  indicating some dissatisfaction with the time it took to complete the questionnaire."                                                                                                                                                                                  1
# Name: count, dtype: int64
# Mode = No
#
# cc_questions_harder_than_expected
# No                                                                                                          31466
# Yes                                                                                                           116
# [Yes/No]                                                                                                       11
# Not applicable                                                                                                  3
# Not applicable to this scenario                                                                                 1
# The customer expressed frustration with the tedious and lengthy process of completing the questionnaire.        1
# "" and also implied that filling it in is not enjoyable."                                                       1
# Name: count, dtype: int64
# Mode = No
#
# cc_dissatisfaction_support
# No                                                                                                                                                                                                         30907
# Yes                                                                                                                                                                                                          681
# [Yes/No]                                                                                                                                                                                                      11
# The customer is frustrated with the repetitive nature of the questionnaire and the time it takes to complete it, mentioning that they usually find it easier to just forward the previous year's email.        1
# Name: count, dtype: int64
# Mode = No
#
# cc_pricing_mentioned
# No               27586
# Yes               3899
# Not Discussed       21
# 90                  14
# 80                  10
# 20                   4
# 70                   2
# 50                   2
# 100                  1
# 95                   1
# 85                   1
# Name: count, dtype: int64
# Mode = No
#
# cc_pricing_sentiment_impact
# No     30508
# Yes     1018
# 90         5
# 80         4
# 70         2
# 20         2
# 95         1
# 85         1
# Name: count, dtype: int64
# Mode = No
#
# cc_refund_discussed
# No     31351
# Yes      183
# 90         5
# 80         1
# 60         1
# Name: count, dtype: int64
# Mode = No
#
# cc_contractor_suggest_leave
# No                                                                                                                                                                                                                        30702
# Yes                                                                                                                                                                                                                         773
# The Contractor did not respond to the Agent's actions.                                                                                                                                                                        3
# The Contractor did not respond to any actions from the Agent.                                                                                                                                                                 2
# The Contractor did not respond to any actions by the Agent as the conversation was incomplete.                                                                                                                                2
#                                                                                                                                                                                                                           ...
#  okay"" when told they would be brought back later."                                                                                                                                                                          1
# The Contractor was satisfied with the Agent's explanation and thanked them for their help.                                                                                                                                    1
# The Contractor was initially frustrated but became more positive as the Agent explained the situation and offered a solution.                                                                                                 1
# The Contractor was appreciative of the Agent's efforts and provided additional information to assist in resolving the issue.                                                                                                  1
# The Agent helped the customer identify and fill in the missing information in his questionnaire, specifically the name and position of the person responsible for environmental management and the references section.        1
# Name: count, Length: 64, dtype: int64
# Mode = No
#
# cc_contractor_complained
# No                                                                                                                                                                                                                      29260
# Yes                                                                                                                                                                                                                      2219
# Not Applicable                                                                                                                                                                                                             50
# The Contractor was appreciative of the Agent's efforts and requested an email to confirm the resolution for their client.                                                                                                   1
# The Agent checked the customer's certificate and verification status, explained the process, and advised the customer to follow up with the customer care advisor.                                                          1
#  implying that they no longer need it."                                                                                                                                                                                     1
# Contractor was appreciative and satisfied with the agent's actions, thanking them for the clarification and assistance.                                                                                                     1
# The Contractor mentioned considering leaving the company due to the frustrating experience and the potential impact on their business.                                                                                      1
# The Contractor was cooperative and understanding throughout the call, and she agreed to follow the Agent's instructions.                                                                                                    1
# The Contractor was appreciative and satisfied with the Agent's actions, thanking them and expressing gratitude for the assistance.                                                                                          1
# The Contractor was cooperative and provided necessary information, and was willing to pay the potential charge to update their accreditation.                                                                               1
# The Contractor was satisfied with the Agent's actions and thanked them for resolving the issue.                                                                                                                             1
# The Contractor mentioned that they wanted to leave because they had obtained an ISO 45001 certification with an SSIP added, making their Safe Contractor accreditation redundant.                                           1
#  feeling that it was a waste of time and money."                                                                                                                                                                            1
# The Agent helped the customer identify the missing work category, explained the process for adding it, and offered to request the addition free of charge due to the customer's recent approval and Premier package.        1
# Name: count, dtype: int64
# Mode = No

# %%
for col in yes_no_columns:
    mode_val = cc_calls[col].mode()[0]
    cc_calls[col] = cc_calls[col].where(cc_calls[col].isin(['Yes', 'No']), other=mode_val)

for col in yes_no_columns:
    print(f"  {col}: {cc_calls[col].nunique()}")
# Out:
#   cc_care_package_discussed: 2
#   cc_urgency_getting_on_site: 2
#   cc_external_consultant: 2
#   cc_agent_cross_sell_attempt: 2
#   cc_customer_issues_concerns: 2
#   cc_business_struggles_financial_hardship: 2
#   cc_questionnaire_completion: 2
#   cc_chasing_response: 2
#   cc_issues_within_questionnaire: 2
#   cc_login_issues: 2
#   cc_platform_issues: 2
#   cc_dissatisfaction_time_to_complete: 2
#   cc_process_complexity_concerns: 2
#   cc_questions_harder_than_expected: 2
#   cc_dissatisfaction_support: 2
#   cc_pricing_mentioned: 2
#   cc_pricing_sentiment_impact: 2
#   cc_refund_discussed: 2
#   cc_contractor_suggest_leave: 2
#   cc_contractor_complained: 2

# %% [markdown]
# Handling null values in cc_calls

# %%
cc_calls.isnull().sum()[cc_calls.isnull().sum() > 0]
# Out:
# cc_contractor_sentiment_start_score        235
# cc_contractor_sentiment_end_score          234
# cc_contractor_sentiment_overall_score     4796
# cc_contractor_sentiment_issues_score     20948
# dtype: int64

# %%
print('Total rows with null values:', cc_calls.isnull().any(axis=1).sum())
# Out:
# Total rows with null values: 20986

# %%
cols = [
    'cc_contractor_sentiment_start_score',
    'cc_contractor_sentiment_end_score'
]

cc_calls = cc_calls.dropna(subset=cols)
cc_calls.shape
# Out:
# (31361, 30)

# %%
print('Total rows with null values:', cc_calls.isnull().any(axis=1).sum())
# Out:
# Total rows with null values: 20711

# %%
score_cols = [
    'cc_contractor_sentiment_overall_score',
    'cc_contractor_sentiment_issues_score'
]

for col in score_cols:
    data = cc_calls[col].dropna()
    mean_val   = round(data.mean(), 2)
    median_val = round(data.median(), 2)
    print(f"Column : {col}")
    print(f"Mean   : {mean_val}")
    print(f"Median : {median_val}")

    plt.figure()
    plt.hist(data, bins=20, color='steelblue', edgecolor='white')
    plt.axvline(mean_val,   color='red',   linestyle='--', label=f'Mean = {mean_val}')
    plt.axvline(median_val, color='green', linestyle='--', label=f'Median = {median_val}')
    plt.title(f'Distribution of {col}')
    plt.xlabel('Score')
    plt.ylabel('Number of rows')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Column : cc_contractor_sentiment_overall_score
# Mean   : 81.59
# Median : 80.0
# Column : cc_contractor_sentiment_issues_score
# Mean   : 80.79
# Median : 90.0

# %% [markdown]
# Histogram shows that both score columns are left skewed. So filling null values with median as it is not affected by outliers.

# %%
for col in score_cols:
    median_val = cc_calls[col].median()
    cc_calls[col] = cc_calls[col].fillna(median_val)

cc_calls.isnull().sum()[cc_calls.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Saving cleaned dataset

# %%
import os
os.makedirs('../../data/cleaned', exist_ok=True)
cc_calls.to_csv('../../data/cleaned/cc_calls_cleaned.csv', index=False)
print('Saved! Shape:', cc_calls.shape)
# Out:
# Saved! Shape: (31361, 30)
